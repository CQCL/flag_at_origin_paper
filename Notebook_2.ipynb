# %% [markdown]
# List of avaliable FT flag circuit varying the distance and the number of qubits for "plaquette":
#
# <table>
#     <tr>
#         <th> </th>
#         <th>2</th>
#         <th>3</th>
#         <th>4</th>
#         <th>5</th>
#         <th>6</th>
#         <th>7</th>
#         <th>8</th>
#         <th>9</th>
#         <th>10</th>
#         <th>11</th>
#         <th>12</th>
#         <th>13</th>
#         <th>14</th>
#         <th>15</th>
#         <th>16</th>
#         <th>17</th>
#         <th>18</th>
#         <th>19</th>
#         <th>20</th>
#         <th>21</th>
#         <th>22</th>
#         <th>23</th>
#         <th>24</th>
#         <th>25</th>
#         <th>26</th>
#         <th>27</th>
#         <th>28</th>
#         <th>29</th>
#         <th>30</th>
#     </tr>
#     <tr>
#         <td>d = 2, 3</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>d = 4, 5</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>2</td>
#         <td>3</td>
#         <td>3</td>
#         <td>3</td>
#         <td>3</td>
#         <td>3</td>
#         <td>3</td>
#         <td>4</td>
#         <td>4</td>
#         <td>4</td>
#         <td>4</td>
#         <td>4</td>
#         <td>4</td>
#         <td>5</td>
#         <td>5</td>
#         <td>5</td>
#         <td>5</td>
#         <td>5</td>
#         <td>5</td>
#         <td>6</td>
#         <td>6</td>
#         <td>6</td>
#         <td>6</td>
#         <td>6</td>
#         <td>6</td>
#     </tr>
#     <tr>
#         <td>d = 6, 7</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>2</td>
#         <td>3</td>
#         <td>4</td>
#         <td>4</td>
#         <td>5</td>
#         <td>5</td>
#         <td>5</td>
#         <td>6</td>
#         <td>6</td>
#         <td>6</td>
#         <td><= 7</td>
#         <td><= 7</td>
#         <td><= 7</td>
#         <td><= 8</td>
#         <td><= 8</td>
#         <td><= 9</td>
#         <td><= 9</td>
#         <td><= 9</td>
#         <td><= 9</td>
#         <td><= 10</td>
#         <td><= 10</td>
#         <td><= 11</td>
#         <td><= 11</td>
#         <td><= 11</td>
#         <td><= 11</td>
#     </tr>
#     <tr>
#         <td>d = 8, 9</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>2</td>
#         <td>3</td>
#         <td>4</td>
#         <td>4</td>
#         <td>6</td>
#         <td>6</td>
#         <td>7</td>
#         <td>7</td>
#         <td>7</td>
#         <td><= 8</td>
#         <td><= 9</td>
#         <td><= 9</td>
#         <td><= 10</td>
#         <td><= 10</td>
#         <td><= 11</td>
#         <td><= 11</td>
#         <td><= 11</td>
#         <td><= 12</td>
#         <td><= 13</td>
#         <td><= 13</td>
#         <td><= 14</td>
#         <td><= 14</td>
#         <td><= 14</td>
#         <td><= 15</td>
#         <td><= 15</td>
#     </tr>
#     <tr>
#         <td>d = 10, 11</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>2</td>
#         <td>3</td>
#         <td>4</td>
#         <td>4</td>
#         <td>6</td>
#         <td>6</td>
#         <td><= 9</td>
#         <td><= 9</td>
#         <td><= 9</td>
#         <td><= 10</td>
#         <td><= 11</td>
#         <td><= 11</td>
#         <td><= 13</td>
#         <td><= 13</td>
#         <td><= 13</td>
#         <td><= 14</td>
#         <td><= 14</td>
#         <td><= 15</td>
#         <td><= 15</td>
#         <td><= 16</td>
#         <td>-</td>
#         <td>-</td>
#         <td>-</td>
#         <td>-</td>
#         <td>-</td>
#     </tr>
# </table>

# %% [markdown]
# Insert the distance of the code and the required number of links to generate a FT plaquette
#
# If you need an even distance look for the corresponding odd distance (ex. distance = 4 -> 5)

# %%
import Notebook_functs as Sf
import importlib
importlib.reload(Sf)  # Reloads the module to include recent changes

Sf.generate_FT_plaq_notebook(5,6) #distance, qubits
# Out:
# <tket::Circuit, qubits=8, gates=22>
# Opening file in browser...
