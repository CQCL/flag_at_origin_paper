# %% [markdown]
# In the following tket, qiskit, and stim circuits for state preparation are provided

# %%
import Notebook_functs as Sf
import importlib
importlib.reload(Sf)  # Reloads the module to include recent changes

# Capture the three circuits
tk_circ, qiskit_circ, stim_circ = Sf.choose_code_stim("[[7,1,3]]")

print("\nQiskit version of the circuit:")
print(qiskit_circ)

# print("\nStim version of the circuit:")
# print(stim_circ)
# Out:
# Circuit Information for key: [[7,1,3]]
# {'entire_circuit': 'SteaneCode.json', 'number_CNOTs': 15, 'number_simQUBITS': 8, 'number_ANC': 3}
# Pytket circuit loaded.
# Number of CNOTs: 15
# Number of Sim Qubits: 8
# Number of Ancillas: 3
#
# Qiskit version of the circuit:
#                  ░ ┌───┐ ░       ░       ░       ░ ┌───┐ ░ ┌─┐                »
#   a[q[3]]: ──────░─┤ X ├─░───────░───────░───────░─┤ X ├─░─┤M├────────────────»
#                  ░ └─┬─┘ ░       ░       ░       ░ └─┬─┘ ░ └╥┘                »
#   a[q[5]]: ──────────┼───────────────────────────────┼──────╫─────────────────»
#                      │                               │      ║  ░ ┌───┐ ░      »
#   a[q[6]]: ──────────┼───────────────────────────────┼──────╫──░─┤ X ├─░──────»
#                  ░   │   ░       ░       ░ ┌───┐ ░   │   ░  ║  ░ └─┬─┘ ░      »
#       q_0: ──────░───┼───░───────░───────░─┤ X ├─░───┼───░──╫──░───┼───░──────»
# ...

# %% [markdown]
# In the following stabilizers used for simulations are provided

# %%
for s in Sf.stabilizers_to_stim_strings_numbered((7,1,3)):
    print(s)
# Out:
# Z1: Z Z Z Z I I I
# Z2: I Z Z I Z Z I
# Z3: I I Z Z I Z Z
# X1: X X X X I I I
# X2: I X X I X X I
# X3: I I X X I X X
# LZ1: Z Z I I Z I I
# LX1: X X I I X I I
